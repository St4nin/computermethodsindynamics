# %% [markdown]
# # Outline
#
# ## Python?
#
# - Python vs. Matlab (Octave)
# - Euler's numerical integration
# - $\LaTeX$
#
# ## Vibrations
#
# - Compare Euler vs. Ode45
# - Vibrations one degree of freedom
#
# ## Amplitude-frequency characteristics
#
# - How it works...
#
# ## Free fall with air resistance
#
# - Numerical solution of an example from lectures
#
# ## Mountain Car
#
# - Nice system for AI learning methods testing (e.g. gym.openai.com)
#
# ## The Fall
#
# - Ideal transportation system for next millenium:)
#
# # Let's find the difference between Python and Matlab?

# %%
from numpy import linspace, sin, pi
from pylab import plot, show, grid

x = linspace(0, 2*pi, 100)
y = sin(x)

plot(x, y)
grid()
show()
